# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(filepath_or_buffer='/opt/d.sidorko/ocr_research/study/mlcourse.ai/data/beauty.csv', sep=';')

# %%
df
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0      5.73     30      0         1      0       1        1        1    14
# 1      4.28     28      0         1      0       1        1        0    12
# 2      7.96     35      0         1      0       1        0        0    10
# 3     11.57     38      0         1      0       0        1        1    16
# 4     11.42     27      0         1      0       0        1        0    16
# ...     ...    ...    ...       ...    ...     ...      ...      ...   ...
# 1255   1.61     25      0         1      1       1        0        1    12
# 1256   1.68      4      0         1      0       1        1        1    12
# 1257   3.29     35      0         1      1       1        0        1    12
# 1258   2.31     15      0         1      1       1        1        1    10
# 1259   1.92     24      0         0      0       1        0        1    16
#
#       looks
# 0         4
# 1         3
# 2         4
# 3         3
# ...

# %%
df['wage']
# Out:
# 0        5.73
# 1        4.28
# 2        7.96
# 3       11.57
# 4       11.42
#         ...
# 1255     1.61
# 1256     1.68
# 1257     3.29
# 1258     2.31
# 1259     1.92
# Name: wage, Length: 1260, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   wage      1260 non-null   float64
#  1   exper     1260 non-null   int64
#  2   union     1260 non-null   int64
#  3   goodhlth  1260 non-null   int64
#  4   black     1260 non-null   int64
#  5   female    1260 non-null   int64
#  6   married   1260 non-null   int64
#  7   service   1260 non-null   int64
#  8   educ      1260 non-null   int64
#  9   looks     1260 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 98.6 KB

# %%
df.describe()
# Out:
#               wage        exper        union     goodhlth        black  \
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      6.306690    18.206349     0.272222     0.933333     0.073810
# std       4.660639    11.963485     0.445280     0.249543     0.261564
# min       1.020000     0.000000     0.000000     0.000000     0.000000
# 25%       3.707500     8.000000     0.000000     1.000000     0.000000
# 50%       5.300000    15.000000     0.000000     1.000000     0.000000
# 75%       7.695000    27.000000     1.000000     1.000000     0.000000
# max      77.720000    48.000000     1.000000     1.000000     1.000000
#
#             female      married      service         educ        looks
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      0.346032     0.691270     0.273810    12.563492     3.185714
# std       0.475892     0.462153     0.446089     2.624489     0.684877
# ...

# %%
df['looks'].hist()
# Out:
# <Axes: >

# %%
df.iloc[:6, 5:7]
# Out:
#    female  married
# 0       1        1
# 1       1        1
# 2       1        0
# 3       0        1
# 4       0        1
# 5       1        1

# %%
toy_df = pd.DataFrame({'age': [24, 35, 49], 'salary': [78, 90, 110]}, index=['A', 'B', 'C'])
toy_df
# Out:
#    age  salary
# A   24      78
# B   35      90
# C   49     110

# %%
toy_df.loc['A', 'age']
# Out:
# np.int64(24)

# %%
def get_person_sex(row):
    return 'female' if row['female'] else 'male'


df['sex'] = df.apply(get_person_sex, axis=1)
df
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0      5.73     30      0         1      0       1        1        1    14
# 1      4.28     28      0         1      0       1        1        0    12
# 2      7.96     35      0         1      0       1        0        0    10
# 3     11.57     38      0         1      0       0        1        1    16
# 4     11.42     27      0         1      0       0        1        0    16
# ...     ...    ...    ...       ...    ...     ...      ...      ...   ...
# 1255   1.61     25      0         1      1       1        0        1    12
# 1256   1.68      4      0         1      0       1        1        1    12
# 1257   3.29     35      0         1      1       1        0        1    12
# 1258   2.31     15      0         1      1       1        1        1    10
# 1259   1.92     24      0         0      0       1        0        1    16
#
#       looks     sex
# 0         4  female
# 1         3  female
# ...

# %%
df.apply('max')
# Out:
# wage        77.72
# exper       48.00
# union        1.00
# goodhlth     1.00
# black        1.00
# female       1.00
# married      1.00
# service      1.00
# educ        17.00
# looks        5.00
# dtype: float64

# %%
df.groupby(by=['female', 'married'])['wage'].agg(['mean'])
# Out:
#                     mean
# female married
# 0      0        5.989578
#        1        7.716778
# 1      0        4.298879
#        1        4.299859

# %%
pd.crosstab(df['looks'], df['married'])
# Out:
# married    0    1
# looks
# 1          5    8
# 2         41  101
# 3        205  517
# 4        127  237
# 5         11    8

# %%
df.groupby(by=['educ'])['wage'].agg(['mean'])
# Out:
#           mean
# educ
# 5     4.587857
# 8     4.969091
# 10    5.524295
# 12    5.698205
# 13    6.642642
# 14    5.613529
# 16    7.792645
# 17    8.661061

# %%
df['wage'].describe(percentiles=[0.05, 0.25, 0.50, 0.75, 0.95])
# Out:
# count    1260.000000
# mean        6.306690
# std         4.660639
# min         1.020000
# 5%          1.980000
# 25%         3.707500
# 50%         5.300000
# 75%         7.695000
# 95%        13.223000
# max        77.720000
# Name: wage, dtype: float64

# %%
sns.boxplot(x='educ', y='wage', data=df[df['wage'] < 30])
# Out:
# <Axes: xlabel='educ', ylabel='wage'>
