# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
#
# Author: [Yury Kashnitsky](https://yorko.github.io). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center> Topic 2. Visual data analysis
# ## <center>Practice. Analyzing "Titanic" passengers
#
# **Fill in the missing code ("You code here"). No need to select answers in a webform.**

# %% [markdown]
# **<a href="https://www.kaggle.com/c/titanic">Competition</a> Kaggle "Titanic: Machine Learning from Disaster".**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.set()
import matplotlib.pyplot as plt

# %% [markdown]
# **Read data**

# %%
train_df = pd.read_csv("../../data/titanic_train.csv", index_col="PassengerId")

# %%
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
train_df.describe(include="all")
# Out:
#           Survived      Pclass                     Name   Sex         Age  \
# count   891.000000  891.000000                      891   891  714.000000
# unique         NaN         NaN                      891     2         NaN
# top            NaN         NaN  Braund, Mr. Owen Harris  male         NaN
# freq           NaN         NaN                        1   577         NaN
# mean      0.383838    2.308642                      NaN   NaN   29.699118
# std       0.486592    0.836071                      NaN   NaN   14.526497
# min       0.000000    1.000000                      NaN   NaN    0.420000
# 25%       0.000000    2.000000                      NaN   NaN   20.125000
# 50%       0.000000    3.000000                      NaN   NaN   28.000000
# 75%       1.000000    3.000000                      NaN   NaN   38.000000
# max       1.000000    3.000000                      NaN   NaN   80.000000
#
#              SibSp       Parch Ticket        Fare Cabin Embarked
# count   891.000000  891.000000    891  891.000000   204      889
# unique         NaN         NaN    681         NaN   147        3
# top            NaN         NaN   1601         NaN    G6        S
# freq           NaN         NaN      7         NaN     4      644
# mean      0.523008    0.381594    NaN   32.204208   NaN      NaN
# std       1.102743    0.806057    NaN   49.693429   NaN      NaN
# min       0.000000    0.000000    NaN    0.000000   NaN      NaN
# 25%       0.000000    0.000000    NaN    7.910400   NaN      NaN
# 50%       0.000000    0.000000    NaN   14.454200   NaN      NaN
# 75%       1.000000    0.000000    NaN   31.000000   NaN      NaN
# max       8.000000    6.000000    NaN  512.329200   NaN      NaN

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# **Let's drop`Cabin`, and then – all rows with missing values.**

# %%
train_df = train_df.drop("Cabin", axis=1).dropna()

# %%
train_df.shape
# Out:
# (712, 10)

# %%
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                       Rice, Mrs. William (Margaret Norton)  female  39.0
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S
# ...            ...    ...               ...      ...      ...
# 886              0      5            382652  29.1250        Q
# 887              0      0            211536  13.0000        S
# 888              0      0            112053  30.0000        S
# 890              0      0            111369  30.0000        C
# 891              0      0            370376   7.7500        Q
#
# [712 rows x 10 columns]

# %% [markdown]
# **1. Build a picture to visualize all scatter plots for each pair of features `Age`, `Fare`, `SibSp`, `Parch` and `Survived`. ( `scatter_matrix ` from Pandas or `pairplot` from Seaborn)**

# %%
features = ['Age', 'Fare', 'SibSp', 'Parch', 'Survived']
sns.pairplot(train_df[features]);

# %% [markdown]
# **2. How does ticket price (`Fare`) depend on `Pclass`? Build a boxplot.**

# %%
sns.boxplot(x='Pclass', y='Fare', data=train_df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# **3. Let's build the same plot but restricting values of `Fare` to be less than 95% quantile of the initial vector (to drop outliers that make the plot less clear).**

# %%
sns.boxplot(x='Pclass', y='Fare', data=train_df[train_df['Fare'] < train_df['Fare'].quantile(0.95)])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
train_df[train_df['Fare'] < train_df['Fare'].quantile(0.95)].groupby(by=['Pclass'])['Fare'].describe()
# Out:
#         count       mean        std   min     25%      50%        75%  \
# Pclass
# 1       146.0  56.380795  27.315206   0.0  30.125  53.1000  78.704175
# 2       173.0  21.471556  13.187429  10.5  13.000  15.0458  26.000000
# 3       355.0  13.229435  10.043158   0.0   7.775   8.0500  15.741700
#
#              max
# Pclass
# 1       113.2750
# 2        73.5000
# 3        56.4958

# %% [markdown]
# **4. How is the percentage of surviving passengers dependent on passengers' gender? Depict it with `Seaborn.countplot` using the `hue` argument.**

# %%
train_df.groupby(by=['Sex'])['Survived'].agg(['count', 'mean'])
# Out:
#         count      mean
# Sex
# female    259  0.752896
# male      453  0.205298

# %%
pd.crosstab(train_df["Sex"], train_df["Survived"])
# Out:
# Survived    0    1
# Sex
# female     64  195
# male      360   93

# %%
sns.countplot(x='Sex', hue='Survived', data=train_df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# **5. How does the distribution of ticket prices differ for those who survived and those who didn't. Depict it with `Seaborn.boxplot`**

# %%
train_df.groupby(by=['Survived'])['Fare'].agg(['count', 'median'])
# Out:
#           count   median
# Survived
# 0           424  11.8875
# 1           288  26.2500

# %%
sns.boxplot(x='Survived', y='Fare', data=train_df[train_df['Fare'] < 500])
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %% [markdown]
# **6. How does survival depend on passengers' age?  Verify (graphically) an assumption that youngsters (< 30 y.o.) survived more frequently than old people (> 55 y.o.).**

# %%
train_df[train_df['Age'] < 30]['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.59375
# 1    0.40625
# Name: proportion, dtype: float64

# %%
train_df[train_df['Age'] > 55]['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.717949
# 1    0.282051
# Name: proportion, dtype: float64

# %%
def get_age_cat(age):
    if age < 30:
        return 'young'
    elif age > 55:
        return 'old'
    else:
        return 'medium'

train_df['age_cat'] = train_df['Age'].apply(get_age_cat)
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                       Rice, Mrs. William (Margaret Norton)  female  39.0
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Embarked age_cat
# PassengerId
# 1                1      0         A/5 21171   7.2500        S   young
# 2                1      0          PC 17599  71.2833        C  medium
# 3                0      0  STON/O2. 3101282   7.9250        S   young
# 4                1      0            113803  53.1000        S  medium
# 5                0      0            373450   8.0500        S  medium
# ...            ...    ...               ...      ...      ...     ...
# 886              0      5            382652  29.1250        Q  medium
# 887              0      0            211536  13.0000        S   young
# 888              0      0            112053  30.0000        S   young
# 890              0      0            111369  30.0000        C   young
# 891              0      0            370376   7.7500        Q  medium
#
# [712 rows x 11 columns]

# %%
sns.countplot(x='age_cat', hue='Survived', data=train_df)
# Out:
# <Axes: xlabel='age_cat', ylabel='count'>

# %%
sns.boxplot(x="Survived", y="Age", data=train_df);

# %%
sns.boxplot(x="Survived", hue="Pclass", y="Age", data=train_df);

# %% [markdown]
# ## Useful resources
# * The same notebook as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-2-practice-visualization) with a [solution](https://www.kaggle.com/kashnitsky/topic-2-practice-solution)
# * Topic 2 "Visual data analysis in Python" as a [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-2-visual-data-analysis-in-python)
# * Main course [site](https://mlcourse.ai), [course repo](https://github.com/Yorko/mlcourse.ai), and YouTube [channel](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
